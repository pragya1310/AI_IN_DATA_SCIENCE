# %% [markdown]
# # **3.2.1 line chart**

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-882e642e-abf2-40b0-9b3e-dd8d0018a38e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-882e642e-abf2-40b0-9b3e-dd8d0018a38e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# imported libraries
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# dataset

# %%
df=pd.read_csv("penguins (1).csv").head(50)
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.shape
# Out:
# (50, 7)

# %% [markdown]
# # Line Plot

# %%
sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
'''sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue='sex')'''
# hue keyword used to make different category in chart like male and female

'''sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue='sex',size=1)'''
# size used to change the size of line (we can take size upto 10 but we can take anynumber it will not show any output)

'''sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue='sex',size=1,palette="autumn")'''
# palette used to change the color

'''sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue='sex',size=1,palette="autumn",style='sex',markers=['o','s'])'''
#style means kis category ko use kar rahe h
# hue  dominant karta h
#markers used to highlight the points in the chart o for circle and s for square.> for triangle

#sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue='sex',size=1,palette="autumn",style='sex',markers=['o','s'],dashes=True)

sns.lineplot(x="bill_length_mm",y="bill_depth_mm",data=df,hue='sex',size=1,palette="autumn",style='sex',markers=['o','s'],dashes=False)
# dashes used to make a line dash like true one line will dash dash and false no change


plt.legend()
plt.show()
